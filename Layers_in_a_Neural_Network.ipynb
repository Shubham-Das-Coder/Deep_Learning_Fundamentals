# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham-Das-Coder/Deep_Learning_Fundamentals/blob/main/Layers_in_a_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *LAYERS IN AN ANN*

# %% [markdown]
# Artificial neural network are typically organized in layers.Different types of layers include

# %% [markdown]
# Dense(or fully connected) Layers

# %% [markdown]
# Convolutional Layers

# %% [markdown]
# Pooling Layers

# %% [markdown]
# Recurrent Layers

# %% [markdown]
# Normalization Layers

# %% [markdown]
# And Many Others

# %%
#Importing necessary packages
from keras.models import Sequential
from keras.layers import Dense,Activation

model=Sequential([ #Setting the variable model to an instance of sequential object
                  Dense(5,input_shape=(3,),activation='relu'), #Creating a dense layer having 5 units, input shape specifies shape of each inputs
                  Dense(2,activation='softmax') #Creating a layer with 2 units, no input shape becauseonly the first layer within the sequential model requires an input shape
])

# %%
pip install --upgrade scipy==1.1.0 #We need older version of Scipy which has 'imread' function

# %%
import numpy as np
from scipy import ndimage
import matplotlib.pyplot as plt
# %matplotlib inline

img=np.expand_dims(ndimage.imread('/content/NN.PNG'),0)
plt.imshow(img[0])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.
